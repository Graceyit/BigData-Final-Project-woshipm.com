# %%
import pandas as pd
df=pd.read_csv('haha.csv', parse_dates=['date'])
df
# Out:
#        Unnamed: 0  Unnamed: 0.1    author       date  favorite  thumb  \
# 0               0           0.0       木公子 2018-11-24        16      7
# 1               1           1.0    姑婆那些事儿 2018-11-23         2      4
# 2               2           2.0      列克星敦 2018-11-23         9      6
# 3               3           3.0        阿嘞 2018-11-23         0      0
# 4               4           4.0      起点学院 2018-11-23         1      0
# 5               5           5.0      大V姐姐 2018-11-22        72     13
# 6               6           6.0  Thinker韩 2018-11-22         6      4
# 7               7           7.0     数商云MA 2018-11-22         2      2
# 8               8           8.0      木木新知 2018-11-22         3      1
# 9               9           9.0      怪兽先森 2018-11-22        10      7
# 10             10          10.0    姑婆那些事儿 2018-11-22         0      0
# 11             11          11.0      神策数据 2018-11-22         7      4
# 12             12          12.0      北京大兵 2018-11-22         4      1
# 13             13          13.0        微笑 2018-11-22        10      7
# 14             14          14.0   fantasy 2018-11-21        11      3
# 15             15          15.0      木木老贼 2018-11-21        19     16
# 16             16          16.0       李金鑫 2018-11-20        20      5
# 17             17          17.0       苏谈彬 2018-11-20        56     49
# 18             18          18.0        韩利 2018-11-20        24     15
# 19             19          19.0     未知素设计 2018-11-20        50      6
# 20             20          20.0    姑婆那些事儿 2018-11-19        10      2
# 21             21          21.0        翁章 2018-11-19         0      2
# 22             22          22.0       高了了 2018-11-19       109     47
# 23             23          23.0       苏谈彬 2018-11-19        12      5
# 24             24          24.0       独孤伤 2018-11-19        15      9
# 25             25          25.0    95后聊科技 2018-11-18        82     35
# 26             26          26.0       王宇庭 2018-11-16         1      6
# 27             27          27.0      怪兽先森 2018-11-15        60     26
# 28             28          28.0      卡思数据 2018-11-15        14      6
# 29             29          29.0      出海运营 2018-11-15         2      1
# ...           ...           ...       ...        ...       ...    ...
# 21318       21329        3072.0        老曹 2012-05-20         1      0
# 21319       21330        3073.0        老曹 2012-05-20         0      0
# 21320       21331        3074.0        老曹 2012-05-20         0      1
# 21321       21332        3075.0        老曹 2012-05-20         1      0
# 21322       21333        3076.0        老曹 2012-05-20         1      0
# 21323       21334        3077.0        老曹 2012-05-20         0      0
# 21324       21335        3078.0        老曹 2012-05-20         2      0
# 21325       21336        3079.0        老曹 2012-05-20         1      0
# 21326       21337        3080.0        老曹 2012-05-20         2      1
# 21327       21338        3081.0        老曹 2012-05-20         3      2
# 21328       21339        3082.0        老曹 2012-05-20         1      0
# 21329       21340        3083.0        老曹 2012-05-20         3      2
# 21330       21341        3084.0        老曹 2012-05-20         0      0
# 21331       21342        3085.0        老曹 2012-05-20         0      1
# 21332       21343        3086.0        老曹 2012-05-20         0      0
# 21333       21344        3087.0        老曹 2012-05-20         0      0
# 21334       21345        3088.0        老曹 2012-05-20         1      0
# 21335       21346        3089.0        老曹 2012-05-20         7      0
# 21336       21347        3090.0        老曹 2012-05-20         1      1
# 21337       21348        3091.0        老曹 2012-05-20        12      2
# 21338       21349        3092.0        老曹 2012-05-20         2      0
# 21339       21350        3093.0        老曹 2012-05-20         3      1
# 21340       21351        3094.0        老曹 2012-05-20        35      1
# 21341       21352        3095.0        老曹 2012-05-20         1      0
# 21342       21353        3096.0        老曹 2012-05-20         9      0
# 21343       21354        3097.0        老曹 2012-05-20         0      0
# 21344       21355        3098.0        老曹 2012-05-20         1      0
# 21345       21356        3099.0        老曹 2012-05-20         0      1
# 21346       21357        3100.0        老曹 2012-05-17        54     16
# 21347       21358        3101.0        老曹 2012-05-17        11     12
#
#                                    title  \
# 0         深度复盘：转化率仅为9%，一次失败的引流课，我总结出了6个坑
# 1                        活动运营最愁啥？人人人人人……
# 2                干货 | 掌握好这6项技能，小白也能成运营高手
# 3                   会员经济时代，做好会员营销的6大关键点！
# 4      小七带你逛起点｜网易运营总监：跟运营前辈能学到什么，不能学到什么？
# 5                   从1000场活动中总结出来的思维套路模型
# 6                      标品与非标品怎么定义?有什么区别?
# 7                 案例+方法：如何打造现金贷产品的用户增长体系
# 8                      你并不知道，什么才是真正的用户需求
# 9                用户对你的产品很满意，为什么还是不肯下单购买？
# 10                         十三条从知乎引流微信的经验
# 11                       数据驱动经验分享：从方法到实践
# 12                  互金运营入门指南（三）：搭建你的运营框架
# 13                    新媒体运营流程：公众号的整个生命周期
# 14             「foodie」近三个月的用户反馈收集、整理及输出
# 15              网易连续不断打造爆款H5，说到底我们可以学什么？
# 16             做产品就是谈恋爱，需要选择和某个人成为长期的合伙人
# 17                             如何构建运营体系？
# 18                        人生运营指南：找个运营来作陪
# 19     如何让用户快乐剁手？请看LINE FRIENDS合作会场的秘密套路
# 20            写得出10W+的文章有什么了不起？能月入10W+吗？
# 21              找到了客群，却输在了投放，ToB营销为何这么难？
# 22                网易系H5频繁刷屏背后，是一个通用的爆款模型
# 23                        如何验证一个点子靠谱不靠谱？
# 24       流量池与社交基因，Luckin coffee和连咖啡的增长之战
# 25                     增长黑客 | 微信读书用户裂变之路
# 26              从钻石营销模式中看：最成功的内容运营策略是什么？
# 27     案例总结：线下门店如何做到两小时引流2000+人， 瞬间刷爆全城？
# 28             目的不同手段也不同，从核心动机看抖音企业号运营逻辑
# 29           如何像TikTok那样赢得海外年轻用户？这里有3个建议
# ...                                  ...
# 21318                        由“标题党”谈开去……
# 21319                       蜕变——记QQ医生3.0
# 21320                     社会化音乐：在夹缝中生出花来
# 21321                    Pivot，信息组织的梦想之窗
# 21322               UPA2009工作坊讲义：统一体验的设计
# 21323                            我给旋风找找茬
# 21324                       浅析“Rich”设计模式
# 21325                                归属感
# 21326                            小标点，大作用
# 21327                   轻设计，让网站灵敏轻便的6个技巧
# 21328                          一见钟情&一见如故
# 21329               分面搜索（Faceted Search）
# 21330                              设计与表达
# 21331                              原型与成就
# 21332            [程序员] 我们在路上 ——QQ旋风2设计历程
# 21333                 实话实说 —— 心理模型vs实现模型
# 21334                    从SNS看社会化界面设计（一）
# 21335                从长尾理论和二八定律的比较去看用户体验
# 21336                          用户体验的时间尺度
# 21337                              面包屑设计
# 21338                             初窥交互设计
# 21339          软件原型设计DIY——揭秘利器UIDesigner
# 21340                             IM X.0
# 21341                            背着包袱跳着走
# 21342                      交互设计方法论 2.0探讨
# 21343                         招聘贴-寻可用性人才
# 21344                             网站氛围漫谈
# 21345            设计只在需要时 —— “暂停”按钮的消失又出现
# 21346                     交互设计入门—交互设计的职能
# 21347                      交互设计入门–了解交互设计
#
#                                         title_href
# 0      http://www.woshipm.com/operate/1656931.html
# 1      http://www.woshipm.com/operate/1656743.html
# 2      http://www.woshipm.com/operate/1656643.html
# 3      http://www.woshipm.com/operate/1655683.html
# 4      http://www.woshipm.com/operate/1650997.html
# 5      http://www.woshipm.com/operate/1654373.html
# 6      http://www.woshipm.com/operate/1653872.html
# 7      http://www.woshipm.com/operate/1653194.html
# 8      http://www.woshipm.com/operate/1653257.html
# 9      http://www.woshipm.com/operate/1652715.html
# 10     http://www.woshipm.com/operate/1650009.html
# 11     http://www.woshipm.com/operate/1649656.html
# 12     http://www.woshipm.com/operate/1651440.html
# 13     http://www.woshipm.com/operate/1651211.html
# 14     http://www.woshipm.com/operate/1648807.html
# 15     http://www.woshipm.com/operate/1649467.html
# 16     http://www.woshipm.com/operate/1647938.html
# 17     http://www.woshipm.com/operate/1645278.html
# 18     http://www.woshipm.com/operate/1644742.html
# 19     http://www.woshipm.com/operate/1641633.html
# 20     http://www.woshipm.com/operate/1642146.html
# 21     http://www.woshipm.com/operate/1636490.html
# 22     http://www.woshipm.com/operate/1610222.html
# 23     http://www.woshipm.com/operate/1638692.html
# 24     http://www.woshipm.com/operate/1638943.html
# 25     http://www.woshipm.com/operate/1634727.html
# 26     http://www.woshipm.com/operate/1631826.html
# 27     http://www.woshipm.com/operate/1629950.html
# 28     http://www.woshipm.com/operate/1628197.html
# 29     http://www.woshipm.com/operate/1630000.html
# ...                                            ...
# 21318         http://www.woshipm.com/ucd/3130.html
# 21319         http://www.woshipm.com/ucd/3131.html
# 21320         http://www.woshipm.com/ucd/3128.html
# 21321         http://www.woshipm.com/ucd/3129.html
# 21322         http://www.woshipm.com/ucd/3127.html
# 21323         http://www.woshipm.com/ucd/3125.html
# 21324         http://www.woshipm.com/ucd/3126.html
# 21325         http://www.woshipm.com/ucd/3123.html
# 21326         http://www.woshipm.com/ucd/3124.html
# 21327         http://www.woshipm.com/ucd/3122.html
# 21328         http://www.woshipm.com/ucd/3120.html
# 21329         http://www.woshipm.com/ucd/3121.html
# 21330         http://www.woshipm.com/ucd/3119.html
# 21331         http://www.woshipm.com/ucd/3118.html
# 21332         http://www.woshipm.com/ucd/3116.html
# 21333         http://www.woshipm.com/ucd/3117.html
# 21334         http://www.woshipm.com/ucd/3115.html
# 21335         http://www.woshipm.com/ucd/3113.html
# 21336         http://www.woshipm.com/ucd/3114.html
# 21337         http://www.woshipm.com/ucd/3112.html
# 21338         http://www.woshipm.com/ucd/3110.html
# 21339         http://www.woshipm.com/ucd/3111.html
# 21340         http://www.woshipm.com/ucd/3108.html
# 21341         http://www.woshipm.com/ucd/3109.html
# 21342         http://www.woshipm.com/ucd/3107.html
# 21343         http://www.woshipm.com/ucd/3106.html
# 21344         http://www.woshipm.com/ucd/3105.html
# 21345         http://www.woshipm.com/ucd/3104.html
# 21346         http://www.woshipm.com/ucd/1672.html
# 21347         http://www.woshipm.com/ucd/1647.html
#
# [21348 rows x 8 columns]

# %%
df['favorite'] = pd.to_numeric(df['favorite'])
df['thumb'] = pd.to_numeric(df['thumb'])

# %%
df['title_length'] = df['title'].apply(len)

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# %%
thumb1=df.sort_values(by='thumb', ascending=False)[:10]
thumb1
# Out:
#        Unnamed: 0  Unnamed: 0.1   author       date  favorite  thumb  \
# 11112       11116         620.0       臻龙 2015-09-29      4317   2193
# 11133       11137         641.0    GaraC 2015-04-20      2141   1886
# 20188       20199        1942.0       朱帝 2014-11-24         9   1406
# 11170       11174         678.0    Nairo 2013-08-19      1466    835
# 9344         9347        1828.0      木木三 2017-04-27       376    735
# 12148       12155         248.0     andy 2018-05-26        86    709
# 8613         8616        1097.0     andy 2017-11-01       647    708
# 3578         3579        1190.0    Nairo 2015-06-23       704    669
# 19870       19881        1624.0  卡卡的人生哲学 2015-08-24      1329    645
# 3212         3213         824.0       留言 2016-11-25      2382    606
#
#                                            title  \
# 11112                           Word产品需求文档，已经过时了
# 11133                     绝密原型档案：看看专业产品经理的原型是什麽样
# 20188                              交互设计初体验(iUED)
# 11170                     Axure教程 axure新手入门基础（1）
# 9344              23天从原型到上线的产品总结（一）：项目开发五大会议过程简述
# 12148                           移动健康管理APP的服务功能分析
# 8613                          产品经理整理PRD时，需要注意哪些点
# 3578   阿里、腾讯、百度产品经理40+道面试题记录：我是怎样同时拿到BAT Offer的？
# 19870                       交互干货必收 | App界面交互设计规范
# 3212                                 产品经理面试习题大汇总
#
#                                            title_href  title_length
# 11112           http://www.woshipm.com/rp/211554.html            16
# 11133           http://www.woshipm.com/rp/149653.html            22
# 20188          http://www.woshipm.com/ucd/121332.html            13
# 11170            http://www.woshipm.com/rp/39203.html            22
# 9344           http://www.woshipm.com/pmd/647298.html            30
# 12148  http://www.woshipm.com/evaluating/1037276.html            16
# 8613           http://www.woshipm.com/pmd/834218.html            18
# 3578      http://www.woshipm.com/zhichang/166482.html            41
# 19870          http://www.woshipm.com/ucd/193776.html            20
# 3212      http://www.woshipm.com/zhichang/459131.html            11

# %%
favorite1=df.sort_values(by='favorite', ascending=False)[:10]
favorite1
# Out:
#        Unnamed: 0  Unnamed: 0.1          author       date  favorite  thumb  \
# 11112       11116         620.0              臻龙 2015-09-29      4317   2193
# 12962       12969        1062.0  梁嘉琪JackieLiang 2016-02-18      2456    257
# 3212         3213         824.0              留言 2016-11-25      2382    606
# 12972       12979        1072.0         休言万事转头空 2016-01-14      2362    247
# 11133       11137         641.0           GaraC 2015-04-20      2141   1886
# 6240         6242        1712.0              臻龙 2017-10-18      1956    560
# 11069       11073         577.0             ygg 2016-02-14      1850    289
# 10941       10945         449.0              浪子 2017-01-16      1614    546
# 11099       11103         607.0     ahu_phoenix 2015-11-05      1478    366
# 11170       11174         678.0           Nairo 2013-08-19      1466    835
#
#                                    title  \
# 11112                   Word产品需求文档，已经过时了
# 12962                       如何去做一份竞品分析报告
# 3212                         产品经理面试习题大汇总
# 12972             你会写报告？产品体验报告的思路应该是这样的！
# 11133             绝密原型档案：看看专业产品经理的原型是什麽样
# 6240              全面解读流程图｜附共享单车摩拜ofo案例分析
# 11069            如何优雅的用Axure装逼？高保真原型心得分享
# 10941            PRD1.0分享：全面通用的移动端产品需求文档
# 11099  Axure制作PRD | 如何用Axure制作“密码管家”需求文档
# 11170             Axure教程 axure新手入门基础（1）
#
#                                           title_href  title_length
# 11112          http://www.woshipm.com/rp/211554.html            16
# 12962  http://www.woshipm.com/evaluating/283737.html            12
# 3212     http://www.woshipm.com/zhichang/459131.html            11
# 12972  http://www.woshipm.com/evaluating/267888.html            22
# 11133          http://www.woshipm.com/rp/149653.html            22
# 6240           http://www.woshipm.com/pd/818876.html            22
# 11069          http://www.woshipm.com/rp/281420.html            23
# 10941          http://www.woshipm.com/rp/575908.html            23
# 11099          http://www.woshipm.com/rp/230437.html            33
# 11170           http://www.woshipm.com/rp/39203.html            22

# %%
df['author'].describe()
# Out:
# count     21348
# unique     3721
# top          老曹
# freq        844
# Name: author, dtype: object

# %%
df['date'].describe()
# Out:
# count                   21348
# unique                   1985
# top       2012-10-20 00:00:00
# freq                      377
# first     2012-05-17 00:00:00
# last      2018-11-25 00:00:00
# Name: date, dtype: object

# %%
df.describe()
# Out:
#          Unnamed: 0  Unnamed: 0.1      favorite         thumb  title_length
# count  21348.000000  21348.000000  21348.000000  21348.000000  21348.000000
# mean   10678.794688   1272.655705     68.872869     17.774030     19.665355
# std     6166.660657    906.902226    116.846543     36.655463      6.307984
# min        0.000000      0.000000     -7.000000      0.000000      3.000000
# 25%     5338.750000    476.000000     14.000000      4.000000     15.000000
# 50%    10677.500000   1112.000000     35.000000      9.000000     19.000000
# 75%    16019.250000   1974.000000     77.000000     20.000000     23.000000
# max    21358.000000   3587.000000   4317.000000   2193.000000     62.000000

# %% [markdown]
# ### Ranking by the number of favorites

# %%
import numpy as np
data=pd.pivot_table(df,values=['favorite'],index='author',aggfunc=[np.sum,np.size])
data['avg']=data[('sum','favorite')]/data[('size','favorite')]
data['avg']=data['avg'].astype('int')

# %%
data.columns=data.columns.get_level_values(0)
data.columns = ['total_favorites','ariticls_num','avg_favorites']

# %%
data=data.query('ariticls_num > 4')

# %%
data_f = data.sort_values(by=['avg_favorites'],ascending=False)
data_f[:10]
# Out:
#                 total_favorites  ariticls_num  avg_favorites
# author
# 臻龙                         7991             5           1598
# windir                     2772             5            554
# 休言万事转头空                    2738             5            547
# Rock                       2732             5            546
# 板栗在飞                       2609             5            521
# 梁嘉琪JackieLiang             2688             6            448
# 妖叶秋                        6026            14            430
# 倒爷001                      2784             7            397
# 胡言                         2734             7            390
# 杨堃                         2446             7            349

# %%
from pyecharts import Bar

attr = ["臻龙", "windir", "休言万事转头空", "Rock", "板栗在飞", "梁嘉琪JackieLiang",'妖叶秋','倒爷001','胡言','杨堃']
# v1 = [7991, 2772, 2738, 2732, 2609, 2688,6026,2784,2734,2446]
v1 = [5, 5, 5, 5, 5,  6,14,7,7,7]
v2 = [1598,554,547,546,521,448,430,397,390,349]
bar = Bar("Favorites Rangking")
# bar.add("Total Favorites", attr, v1,xaxis_interval=0, xaxis_rotate=30,mark_point=["average"])
bar.add("Ariticls Number", attr, v1,xaxis_interval=0, xaxis_rotate=30, mark_point=["min"])
bar.add("Average Favorites", attr, v2,xaxis_interval=0, xaxis_rotate=30, mark_point=["max"])
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="76a0c2f937f24ae384c6fcf7fa339633" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_76a0c2f937f24ae384c6fcf7fa339633 = echarts.init(document.getElementById('76a0c2f937f24ae384c6fcf7fa339633'), 'light', {renderer: 'canvas'});
#
# var option_76a0c2f937f24ae384c6fcf7fa339633 = {
#     "title": [
#         {
#             "text": "Favorites Rangking",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 1332899,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "Ariticls Number",
#             "data": [
#                 5,
#                 5,
#                 5,
#                 5,
#                 5,
#                 6,
#                 14,
#                 7,
#                 7,
#                 7
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "min",
#                         "name": "Minimum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 1332899
#         },
#         {
#             "type": "bar",
#             "name": "Average Favorites",
#             "data": [
#                 1598,
#                 554,
#                 547,
#                 546,
#                 521,
#                 448,
#                 430,
#                 397,
#                 390,
#                 349
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 1332899
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Ariticls Number",
#                 "Average Favorites"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": 0,
#                 "rotate": 30,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u81fb\u9f99",
#                 "windir",
#                 "\u4f11\u8a00\u4e07\u4e8b\u8f6c\u5934\u7a7a",
#                 "Rock",
#                 "\u677f\u6817\u5728\u98de",
#                 "\u6881\u5609\u742aJackieLiang",
#                 "\u5996\u53f6\u79cb",
#                 "\u5012\u7237001",
#                 "\u80e1\u8a00",
#                 "\u6768\u5803"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_76a0c2f937f24ae384c6fcf7fa339633.setOption(option_76a0c2f937f24ae384c6fcf7fa339633);
#
#     });
# </script>

# %% [markdown]
# ### Ranking by the number of published atricles

# %%
data_a = data.sort_values(by=['ariticls_num'],ascending=False)
data_a[:10]
# Out:
#         total_favorites  ariticls_num  avg_favorites
# author
# 老曹                 4012           844              4
# 米可                37760           704             53
# yoyo              25461           442             57
# Alice             24177           426             56
# Anne              16833           372             45
# Ella              20175           309             65
# XO小喵              15504           306             50
# 刘旷                 4120           241             17
# 产品周报               1378           200              6
# Nairo             15337           199             77

# %%
from pyecharts import Bar

attr = ["老曹", "米可", "yoyo", "Alice", "Anne", "Ella",'XO小喵','刘旷','产品周报','Nairo']
# v1 = [4012, 37760, 25461, 24177, 16833, 20175,15504,4120,1378,15337]
v2 = [844, 704, 442, 426, 372, 309,306,241,200,199]
v3 = [4,53,57,56,45,65,50,17,6,77]
bar = Bar("Articles Ranking")
# bar.add("Total Favorites", attr, v1, xaxis_interval=0, xaxis_rotate=30,mark_point=["average"])
bar.add("Ariticls Number", attr, v2,xaxis_interval=0, xaxis_rotate=30,mark_point=["max"])
bar.add("Average Favorites", attr, v3, xaxis_interval=0, xaxis_rotate=30,mark_point=["average"])
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="92793ae995dd4fac80d19c3298f8b11d" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_92793ae995dd4fac80d19c3298f8b11d = echarts.init(document.getElementById('92793ae995dd4fac80d19c3298f8b11d'), 'light', {renderer: 'canvas'});
#
# var option_92793ae995dd4fac80d19c3298f8b11d = {
#     "title": [
#         {
#             "text": "Articles Ranking",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 5264792,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "Ariticls Number",
#             "data": [
#                 844,
#                 704,
#                 442,
#                 426,
#                 372,
#                 309,
#                 306,
#                 241,
#                 200,
#                 199
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "max",
#                         "name": "Maximum",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 5264792
#         },
#         {
#             "type": "bar",
#             "name": "Average Favorites",
#             "data": [
#                 4,
#                 53,
#                 57,
#                 56,
#                 45,
#                 65,
#                 50,
#                 17,
#                 6,
#                 77
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value",
#                         "symbol": "pin",
#                         "symbolSize": 50,
#                         "label": {
#                             "normal": {
#                                 "textStyle": {
#                                     "color": "#fff"
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 5264792
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Ariticls Number",
#                 "Average Favorites"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": 0,
#                 "rotate": 30,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u8001\u66f9",
#                 "\u7c73\u53ef",
#                 "yoyo",
#                 "Alice",
#                 "Anne",
#                 "Ella",
#                 "XO\u5c0f\u55b5",
#                 "\u5218\u65f7",
#                 "\u4ea7\u54c1\u5468\u62a5",
#                 "Nairo"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_92793ae995dd4fac80d19c3298f8b11d.setOption(option_92793ae995dd4fac80d19c3298f8b11d);
#
#     });
# </script>

# %%
臻龙老曹

# %%
from pyecharts import Radar
v1 = [[7991,5,1598]]
v2 = [[4012,844,4]]
c_schema= [{"name": "总点赞数", "max": 8000, "min": 1},
           {"name": "文章数", "max": 850, "min": 1},
           {"name": "平均点赞数", "max": 1600, "min": 1}]
radar = Radar()
radar.config(c_schema=c_schema, shape='circle')
radar.add("臻龙", v1, item_color="#f9713c", symbol=None)
radar.add("老曹", v2, item_color="#4e79a7", symbol=None)
radar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="a00d7be90b8446a88bfb7840b32e25c6" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_a00d7be90b8446a88bfb7840b32e25c6 = echarts.init(document.getElementById('a00d7be90b8446a88bfb7840b32e25c6'), 'light', {renderer: 'canvas'});
#
# var option_a00d7be90b8446a88bfb7840b32e25c6 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 2436188,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "radar",
#             "name": "\u81fb\u9f99",
#             "data": [
#                 [
#                     7991,
#                     5,
#                     1598
#                 ]
#             ],
#             "symbol": "none",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "itemStyle": {
#                 "normal": {
#                     "color": "#f9713c"
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         },
#         {
#             "type": "radar",
#             "name": "\u8001\u66f9",
#             "data": [
#                 [
#                     4012,
#                     844,
#                     4
#                 ]
#             ],
#             "symbol": "none",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "itemStyle": {
#                 "normal": {
#                     "color": "#4e79a7"
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u81fb\u9f99",
#                 "\u8001\u66f9"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "radar": {
#         "indicator": [
#             {
#                 "name": "\u603b\u70b9\u8d5e\u6570",
#                 "max": 8000,
#                 "min": 1
#             },
#             {
#                 "name": "\u6587\u7ae0\u6570",
#                 "max": 850,
#                 "min": 1
#             },
#             {
#                 "name": "\u5e73\u5747\u70b9\u8d5e\u6570",
#                 "max": 1600,
#                 "min": 1
#             }
#         ],
#         "shape": "circle",
#         "name": {
#             "textStyle": {
#                 "color": "#333",
#                 "fontSize": 12
#             }
#         },
#         "splitLine": {
#             "show": true,
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         },
#         "splitArea": {
#             "show": true,
#             "areaStyle": {
#                 "opacity": 1
#             }
#         },
#         "axisLine": {
#             "show": true,
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     },
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_a00d7be90b8446a88bfb7840b32e25c6.setOption(option_a00d7be90b8446a88bfb7840b32e25c6);
#
#     });
# </script>
