# %%
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt

df = pd.read_csv('业界动态.csv') 

plt.rcParams['font.sans-serif']=['SimHei'] 
plt.rcParams['axes.unicode_minus']=False 

author_counts=df['author'].value_counts()[:10].sort_values(ascending=False) 
author = pd.DataFrame(author_counts)
fig = plt.figure(figsize=(14,7)) 
plt.bar(author.index, author.author,color = '#4584b6',edgecolor = '#4584b6') 

plt.title('top 10 author') 
plt.xlabel('author')
plt.ylabel('counts')
plt.show()

# %%
import seaborn as sns
sns.set(font='SimHei') 
pd_df = df.groupby(['author'])['thumb'].mean().reset_index().sort_values("thumb",ascending=False) [:10]
ax = sns.barplot(x='author', y='thumb',data=pd_df,palette=("ch:2.5,-.2,dark=.3")) 
plt.title('author_thumb', color='black', fontsize=15, weight='bold')
# Out:
# Text(0.5,1,'author_thumb')

# %%
thumb_favorite = df[['thumb','favorite']]
ax4 = thumb_favorite.plot(kind = 'scatter',x='thumb',y='favorite',color = '#575ed8',s=80,fontsize=24)
ax4.set_title("业界动态点赞收藏关系图",fontsize=20)
# Out:
# Text(0.5,1,'业界动态点赞收藏关系图')

# %%
import plotly
import plotly.graph_objs as go
df2 = df.groupby(['author'])['favorite'].mean().reset_index().sort_values("favorite",ascending=False)
df2_1 =df2[:10]
data = [go.Bar(x=df2.author, y=df2_1.favorite)]
plotly.offline.plot(data, filename='author_with_favorite_bar-业界动态')
# Out:
# /Users/huashanzeng/anaconda3/lib/python3.7/site-packages/plotly/offline/offline.py:621: UserWarning:
#
# Your filename `author_with_favorite_bar-业界动态` didn't end with .html. Adding .html to the end of your file.
# 'file:///Users/huashanzeng/Untitled Folder/author_with_favorite_bar-业界动态.html'

# %%
import pyecharts
from pyecharts import Bar

df3 = df.groupby(['author'])['thumb'].mean().reset_index().sort_values("thumb",ascending=False)
df3_1 = df3[:10]
attr = df3_1.author
v2 = df3_1.thumb
bar = Bar("authors by thumb")
bar.add("thumb", attr, v2, mark_line=["average"])
attr = df2_1.author
v2 = df2_1.favorite
bar_1 = Bar("authors by favorite")
bar_1.add("by favorite", attr, v2, mark_line=["average"])

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="657cd27d46344ae98215bf63d1bc4c41" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_657cd27d46344ae98215bf63d1bc4c41 = echarts.init(document.getElementById('657cd27d46344ae98215bf63d1bc4c41'), 'light', {renderer: 'canvas'});
#
# var option_657cd27d46344ae98215bf63d1bc4c41 = {
#     "title": [
#         {
#             "text": "authors by thumb",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 8930673,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "thumb",
#             "data": [
#                 137.33333333333334,
#                 108.0,
#                 98.0,
#                 96.0,
#                 93.0,
#                 92.0,
#                 87.0,
#                 84.0,
#                 75.0,
#                 71.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 8930673
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "thumb"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "andy",
#                 "\u4f55\u55b5\u55b5",
#                 "\u5a9b\u5a9b\u5927\u738b",
#                 "\u96f600\u9759",
#                 "\u4ea7\u54c1\u4eba\u767d\u82c7",
#                 "\u795e\u6237\u77ed\u90ce",
#                 "\u4e8e\u8a00\u67d0",
#                 "SKY#\u6c99\u94c9\u7693",
#                 "\u4e0d\u8d77\u540d\u5b57\u4e86",
#                 "\u7b80\u626c"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_657cd27d46344ae98215bf63d1bc4c41.setOption(option_657cd27d46344ae98215bf63d1bc4c41);
#
#     });
# </script>

# %%
bar_1
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="37db40c3cf724f1bac8da7a98b77c50c" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_37db40c3cf724f1bac8da7a98b77c50c = echarts.init(document.getElementById('37db40c3cf724f1bac8da7a98b77c50c'), 'light', {renderer: 'canvas'});
#
# var option_37db40c3cf724f1bac8da7a98b77c50c = {
#     "title": [
#         {
#             "text": "authors by favorite",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 6636921,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "by favorite",
#             "data": [
#                 534.0,
#                 518.0,
#                 357.0,
#                 353.0,
#                 278.0,
#                 270.0,
#                 224.0,
#                 222.0,
#                 211.0,
#                 207.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 6636921
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "by favorite"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u795e\u6237\u77ed\u90ce",
#                 "\u4e8e\u8a00\u67d0",
#                 "\u8c22\u8001\u5e08",
#                 "\u96f600\u9759",
#                 "Kevin",
#                 "\u8bfa\u8bfaaa11",
#                 "\u8c4c\u4fa0",
#                 "\u9648\u5f20\u826f",
#                 "\u5a9b\u5a9b\u5927\u738b",
#                 "Blues"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_37db40c3cf724f1bac8da7a98b77c50c.setOption(option_37db40c3cf724f1bac8da7a98b77c50c);
#
#     });
# </script>

# %%
df["thumb"].describe()
# Out:
# count    3588.000000
# mean        9.546265
# std        13.996847
# min         0.000000
# 25%         3.000000
# 50%         6.000000
# 75%        11.000000
# max       234.000000
# Name: thumb, dtype: float64

# %%
df[df["thumb"]>100]
# Out:
#       Unnamed: 0    author        date  favorite  thumb  \
# 363          363     纸盒小卡车  2018/10/17       211    139
# 468          468     辩手李慕阳  2018/09/26       165    110
# 469          469        米可  2018/09/26       144    115
# 588          588        米可  2018/09/10       146    190
# 700          700      andy  2018/08/27        41    134
# 835          835     纸盒小卡车  2018/08/06       345    164
# 1085        1085     不起名字了  2018/06/29        21    118
# 1109        1109     产品人白苇  2018/06/23        49    101
# 1527        1527       何喵喵  2018/04/09       196    108
# 1606        1606      平章大人  2018/03/26        95    112
# 1759        1759      平章大人  2018/02/25        84    110
# 1778        1778      平章大人  2018/02/12        28    104
# 1840        1840  人人都是产品经理  2018/01/29       536    146
# 2039        2039      andy  2017/12/22        79    135
# 2404        2404      andy  2017/10/28        86    143
# 3059        3059     Alice  2017/07/09       163    234
# 3470        3470     辩手李慕阳  2017/04/22       333    145
#
#                            title                              title_href
# 363                      阿里云这群疯子  http://www.woshipm.com/it/1520333.html
# 468         互联网凛冬将至，送你一份“寒冬”抗冻指南  http://www.woshipm.com/it/1456184.html
# 469                      移动互联网十年  http://www.woshipm.com/it/1456007.html
# 588              滴滴的产品经理，请你进来看一下  http://www.woshipm.com/it/1391171.html
# 700                   如何做好移动健康管理  http://www.woshipm.com/it/1296492.html
# 835                         抖音设局  http://www.woshipm.com/it/1215172.html
# 1085       素质教育未来与教育系统合作方案的可行性分析   http://www.woshipm.com/it/888887.html
# 1109               从产品迭代看微信的电商尝试  http://www.woshipm.com/it/1069601.html
# 1527               新人产品经理常见的十种错误   http://www.woshipm.com/it/985974.html
# 1606          价格门的启示：滴滴的焦虑，美团的野望   http://www.woshipm.com/it/971800.html
# 1759               浅析京东的无界零售战略布局   http://www.woshipm.com/it/939794.html
# 1778  思考：每年几十亿+人流，如何布局火车站这个线下场景？   http://www.woshipm.com/it/937822.html
# 1840                 2017产品经理白皮书   http://www.woshipm.com/it/925986.html
# 2039                 大数据在医疗领域的应用   http://www.woshipm.com/it/882593.html
# 2404             移动医疗汇总分析：图解移动医疗   http://www.woshipm.com/it/829502.html
# 3059       知识付费这两年，我花5000元买的4个教训   http://www.woshipm.com/it/712903.html
# 3470             社交并未死亡，高端局才刚刚开始   http://www.woshipm.com/it/644132.html

# %%
df["author"].describe()
# Out:
# count     3588
# unique     818
# top         刘旷
# freq       216
# Name: author, dtype: object

# %%
df[df["thumb"]>50].describe()
# Out:
#         Unnamed: 0    favorite       thumb
# count    57.000000   57.000000   57.000000
# mean   1715.315789  152.842105   90.561404
# std    1049.426104  127.226007   37.085335
# min     263.000000   12.000000   51.000000
# 25%     912.000000   71.000000   61.000000
# 50%    1536.000000  129.000000   80.000000
# 75%    2404.000000  187.000000  108.000000
# max    3544.000000  536.000000  234.000000

# %%
df[df["favorite"]>50].describe()
# Out:
#         Unnamed: 0    favorite       thumb
# count   494.000000  494.000000  494.000000
# mean   1956.006073   94.410931   27.574899
# std    1002.247664   59.219185   26.337593
# min      41.000000   51.000000    2.000000
# 25%    1136.000000   60.000000   13.000000
# 50%    1888.500000   76.000000   20.000000
# 75%    2877.750000  104.750000   32.000000
# max    3583.000000  536.000000  234.000000

# %%
df[(df["thumb"]>50)&(df["favorite"]>50)].describe()
# Out:
#         Unnamed: 0    favorite       thumb
# count    46.000000   46.000000   46.000000
# mean   1799.086957  183.304348   92.630435
# std    1077.977609  123.212169   38.904075
# min     275.000000   55.000000   51.000000
# 25%     926.250000   92.750000   63.500000
# 50%    1566.000000  145.000000   81.500000
# 75%    2888.250000  210.250000  109.500000
# max    3544.000000  536.000000  234.000000
