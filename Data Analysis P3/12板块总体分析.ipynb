# %%
# !pip install pyecharts_snapshot

# %%
import pyecharts
from pyecharts import Style
from pyecharts import Pie

pie = Pie('The share of the popular articles with thumb and favorite more than 50', "数据来源：人人都是产品经理", title_pos='center')
style = Style()
pie_style = style.add(
    label_pos="center",
    is_label_show=True,
    label_text_color=None
)

pie.add(
    "", ["人工智能", ""], [2, 367], center=[15, 30], radius=[18, 24], **pie_style
)
pie.add(
    "", ["blockchain", ""], [3, 198], center=[30, 30], radius=[18, 24], **pie_style
)
pie.add(
    "", ["业界动态", ""], [46, 3542], center=[45, 30], radius=[18, 24], **pie_style
)
pie.add(
    "", ["交互体验", ""], [123, 2979], center=[60, 30], radius=[18, 24], **pie_style
)
pie.add(
    "", ["产品经理", ""], [397, 2579], center=[75, 30], radius=[18, 24], **pie_style
)
pie.add(
    "", ["产品运营", ""], [145, 2243], center=[90, 30], radius=[18, 24], **pie_style
)
pie.add(
    "", ["分析评测", ""], [174, 1089], center=[15, 75], radius=[18, 24], **pie_style
)
pie.add(
    "", ["创业学院", ""], [275, 851], center=[30, 75], radius=[18, 24], **pie_style
)
pie.add(
    "", ["职场攻略", ""], [126, 2014], center=[45, 75], radius=[18, 24], **pie_style
)
pie.add(
    "", ["营销推广", ""], [13, 473], center=[60, 75], radius=[18, 24], **pie_style
)
pie.add(
    "", ["原型设计", ""], [115, 606], center=[75, 75], radius=[18, 24], **pie_style
)
pie.add(
    "", ["产品设计", ""], [155, 2833], center=[90, 75], radius=[18, 24], legend_top="center", **pie_style
)
pie.render()
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="ef85eddf65114f568ca2c5ccea806ca5" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_ef85eddf65114f568ca2c5ccea806ca5 = echarts.init(document.getElementById('ef85eddf65114f568ca2c5ccea806ca5'), 'light', {renderer: 'canvas'});
#
# var option_ef85eddf65114f568ca2c5ccea806ca5 = {
#     "title": [
#         {
#             "text": "The share of the popular articles with thumb and favorite more than 50",
#             "subtext": "\u6570\u636e\u6765\u6e90\uff1a\u4eba\u4eba\u90fd\u662f\u4ea7\u54c1\u7ecf\u7406",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
# ...

# %%
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt

df = pd.read_csv('热门课程.csv') 
df
# Out:
#     Unnamed: 0                        city           duration  \
# 0            0  北京/上海/深圳/广州/杭州/成都/南京/厦门/武汉    2天线下闭门培训+1年在线学习
# 1            1                        全国开课  10周在线学习+1V1跟踪学习服务
# 2            2                    北京/上海/深圳    2天线下闭门培训+1年在线学习
# 3            3           北京/上海/深圳/广州/杭州/成都    2天线下闭门培训+1年在线学习
# 4            4                    北京/上海/深圳    2天线下闭门培训+1年在线学习
# 5            5                    北京/上海/深圳           2天线下闭门培训
# 6            6              直播+录播+作业+答疑+实战            90天在线学习
# 7            7              直播+录播+作业+答疑+实战            90天在线学习
# 8            8                         NaN                NaN
# 9            9                         NaN                NaN
# 10          10                         NaN                NaN
# 11          11                         NaN                NaN
# 12          12                         NaN                NaN
# 13          13                         NaN                NaN
# ...

# %%
 df['city'].describe()
# Out:
# count            8
# unique           5
# top       北京/上海/深圳
# freq             3
# Name: city, dtype: object

# %%
# !pip install echarts-countries-pypkg
# !pip install echarts-china-provinces-pypkg
# !pip install echarts-china-cities-pypkg

# %%
from pyecharts import Bar

attr = ["最高產作者發文量", "平均點讚最高之數量", "平均收藏最高之數量", "點讚數大於50文章數", "收藏大於50文章數", "板塊全部發文量"]
v1 = [38, 208, 187, 3, 40, 369]
v2 = [24, 257, 317.3, 3, 40, 201]
v3 = [216, 137.3, 534, 57, 494, 3588]
v4 = [414, 397, 1158, 139, 971, 3102]
v5 = [65, 735, 1365, 405, 1865, 2976]
v6 = [107, 560, 1956, 165, 1384, 2988]
v7 = [59, 179, 614, 148, 1128, 2388]
v8 = [20, 394.5, 2362, 177, 789, 1263]
v9 = [102, 198, 552, 22, 275, 1126]
v10 = [46, 1193, 2590, 117, 452, 721]
v11 = [420, 357.5, 1427, 150, 545, 2140]
v12 = [39, 211, 293, 13, 97, 486]
bars = Bar("")
bars.add("人工智能", attr, v1, is_stack=True)
bars.add("區塊鏈", attr, v2, is_stack=True)
bars.add("業界動態", attr, v3, is_stack=True)
bars.add("交互體驗", attr, v4, is_stack=True)
bars.add("產品經理", attr, v5, is_stack=True)
bars.add("產品設計", attr, v6, is_stack=True)
bars.add("產品運營", attr, v7, is_stack=True)
bars.add("分析評測", attr, v8, is_stack=True)
bars.add("創業學院", attr, v9, is_stack=True)
bars.add("原型設計", attr, v10, is_stack=True)
bars.add("職場攻略", attr, v11, is_stack=True)
bars.add("營銷推廣", attr, v12, is_stack=True)
bars.render()
bars
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="0f69011921a146cb975a25243e01516c" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_0f69011921a146cb975a25243e01516c = echarts.init(document.getElementById('0f69011921a146cb975a25243e01516c'), 'light', {renderer: 'canvas'});
#
# var option_0f69011921a146cb975a25243e01516c = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
# ...

# %%
from pyecharts import Bar

# %%
import random

attr = ['人工智能', '區塊鏈', '業界動態', '交互體驗', '產品經理', '產品設計', '產品運營', '分析評測', '創業學院', '原型設計', '職場攻略', '營銷推廣']
v1 = [369, 201, 3588, 3102, 2976, 2988, 2388, 1263, 1126, 721, 2140, 486]
bar = Bar("12个板块发文量比较图")
bar.add("", attr, v1, is_label_show=True, is_datazoom_show=True)
bar.render()
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="295682c383224d52b9a8c8ce959dc0f8" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_295682c383224d52b9a8c8ce959dc0f8 = echarts.init(document.getElementById('295682c383224d52b9a8c8ce959dc0f8'), 'light', {renderer: 'canvas'});
#
# var option_295682c383224d52b9a8c8ce959dc0f8 = {
#     "title": [
#         {
#             "text": "12\u4e2a\u677f\u5757\u53d1\u6587\u91cf\u6bd4\u8f83\u56fe",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
# ...

# %%
import random

attr = ['智能相对轮(人工智能)', '蓝狐笔记(區塊鏈)', '刘旷(業界動態)', '老曹(交互體驗)', '枯叶(產品經理)', ' Alice(產品設計)', '米可(產品運營)', 'Nairo(分析評測)', '米可(創業學院)', '浪子(原型設計)', '老曹(職場攻略)', '米可(營銷推廣)']
v1 = [38, 24, 216, 414, 65, 107, 59, 20, 102, 46, 420, 39]
bar = Bar("12个最高产作者产量比较图")
bar.add("", attr, v1, is_label_show=True, is_datazoom_show=True)
bar.render()
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="d898680be15647d1910af4365db5676e" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_d898680be15647d1910af4365db5676e = echarts.init(document.getElementById('d898680be15647d1910af4365db5676e'), 'light', {renderer: 'canvas'});
#
# var option_d898680be15647d1910af4365db5676e = {
#     "title": [
#         {
#             "text": "12\u4e2a\u6700\u9ad8\u4ea7\u4f5c\u8005\u4ea7\u91cf\u6bd4\u8f83\u56fe",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
# ...

# %%
from pyecharts import Bar

attr = ['人工智能(智能相对论)', '區塊鏈(蓝狐笔记)', '業界動態(刘旷)', '交互體驗(老曹)', '產品經理(枯叶)', ' 產品設計(Alice)', '產品運營(米可)', '分析評測(Nairo)', '創業學院(米可)', '原型設計(浪子)', '職場攻略(老曹)', '營銷推廣(米可)']
v1 = [369, 201, 3588, 3102, 2976, 2988, 2388, 1263, 1126, 721, 2140, 486]
v2 = [38, 24, 216, 414, 65, 107, 59, 20, 102, 46, 420, 39]
bar = Bar("")
bar.add("The total number", attr, v1, is_stack=True, is_datazoom_show=True)
bar.add("The number of articles written by the most productive authors", attr, v2, is_stack=True, is_datazoom_show=True)
bar.render()
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="1a94d39a54a04c788d75cbfae0a88ed9" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_1a94d39a54a04c788d75cbfae0a88ed9 = echarts.init(document.getElementById('1a94d39a54a04c788d75cbfae0a88ed9'), 'light', {renderer: 'canvas'});
#
# var option_1a94d39a54a04c788d75cbfae0a88ed9 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
# ...
