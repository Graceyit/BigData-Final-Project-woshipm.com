# %%
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt

df = pd.read_csv('产品经理.csv') 

plt.rcParams['font.sans-serif']=['SimHei'] 
plt.rcParams['axes.unicode_minus']=False 

author_counts=df['author'].value_counts()[:10].sort_values(ascending=False) 
author = pd.DataFrame(author_counts)
fig = plt.figure(figsize=(14,7)) 
plt.bar(author.index, author.author,color = '#4584b6',edgecolor = '#4584b6') 

plt.title('top 10 author') 
plt.xlabel('author')
plt.ylabel('counts')
plt.show()

# %%
import seaborn as sns
sns.set(font='SimHei') 
pd_df = df.groupby(['author'])['thumb'].mean().reset_index().sort_values("thumb",ascending=False) [:10]
ax = sns.barplot(x='author', y='thumb',data=pd_df,palette=("ch:2.5,-.2,dark=.3")) 
plt.title('author_thumb', color='black', fontsize=15, weight='bold')
# Out:
# Text(0.5,1,'author_thumb')

# %%
thumb_favorite = df[['thumb','favorite']]
ax4 = thumb_favorite.plot(kind = 'scatter',x='thumb',y='favorite',color = '#575ed8',s=80,fontsize=24)
ax4.set_title("产品经理收藏点赞关系图",fontsize=20)
# Out:
# Text(0.5,1,'产品经理收藏点赞关系图')

# %%
df["author"].describe()
# Out:
# count     2976
# unique    1103
# top         枯叶
# freq        65
# Name: author, dtype: object

# %%
df[df["thumb"]>50].describe()
# Out:
#         Unnamed: 0     favorite       thumb
# count   405.000000   405.000000  405.000000
# mean   1525.123457   334.293827   92.471605
# std     790.607565   220.229819   64.153608
# min      16.000000     9.000000   51.000000
# 25%     878.000000   196.000000   59.000000
# 50%    1644.000000   285.000000   74.000000
# 75%    2125.000000   413.000000  103.000000
# max    2972.000000  1462.000000  735.000000

# %%
df[df["favorite"]>50].describe()
# Out:
#         Unnamed: 0     favorite        thumb
# count  1865.000000  1865.000000  1865.000000
# mean   1611.215550   161.927614    37.894906
# std     817.794501   147.219241    41.682670
# min      16.000000    51.000000     0.000000
# 25%     920.000000    74.000000    16.000000
# 50%    1646.000000   112.000000    26.000000
# 75%    2324.000000   188.000000    45.000000
# max    2974.000000  1462.000000   735.000000

# %%
df[(df["thumb"]>50)&(df["favorite"]>50)].describe()
# Out:
#         Unnamed: 0     favorite       thumb
# count   397.000000   397.000000  397.000000
# mean   1538.904282   340.443325   91.768262
# std     785.095005   218.080017   62.991235
# min      16.000000    55.000000   51.000000
# 25%     896.000000   199.000000   59.000000
# 50%    1653.000000   288.000000   74.000000
# 75%    2126.000000   415.000000  102.000000
# max    2972.000000  1462.000000  735.000000
