# %%
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt

df = pd.read_csv('blockchain.csv') 

plt.rcParams['font.sans-serif']=['SimHei'] 
plt.rcParams['axes.unicode_minus']=False 

author_counts=df['author'].value_counts()[:10].sort_values(ascending=False) 
author = pd.DataFrame(author_counts)
fig = plt.figure(figsize=(14,7)) 
plt.bar(author.index, author.author,color = '#4584b6',edgecolor = '#4584b6') 

plt.title('top 10 author') 
plt.xlabel('author')
plt.ylabel('counts')
plt.show()

# %%
import seaborn as sns
sns.set(font='SimHei') 
pd_df = df.groupby(['author'])['thumb'].mean().reset_index().sort_values("thumb",ascending=False) [:10]
ax = sns.barplot(x='author', y='thumb',data=pd_df,palette=("ch:2.5,-.2,dark=.3")) 
plt.title('author_thumb', color='black', fontsize=15, weight='bold')
# Out:
# Text(0.5,1,'author_thumb')

# %%
thumb_favorite = df[['thumb','favorite']]
ax4 = thumb_favorite.plot(kind = 'scatter',x='thumb',y='favorite',color = '#575ed8',s=80,fontsize=24)
ax4.set_title("thumb with favorite count",fontsize=20)
# Out:
# Text(0.5,1,'thumb with favorite count')

# %%
import plotly
import plotly.graph_objs as go
df2 = df.groupby(['author'])['favorite'].mean().reset_index().sort_values("favorite",ascending=False)
df2_1 =df2[:10]
data = [go.Bar(x=df2.author, y=df2_1.favorite)]
plotly.offline.plot(data, filename='author_with_favorite_bar-业界动态')
# Out:
# /Users/huashanzeng/anaconda3/lib/python3.7/site-packages/plotly/offline/offline.py:621: UserWarning:
#
# Your filename `author_with_favorite_bar-业界动态` didn't end with .html. Adding .html to the end of your file.
# 'file:///Users/huashanzeng/Untitled Folder/author_with_favorite_bar-业界动态.html'

# %%
import pyecharts
from pyecharts import Bar

df3 = df.groupby(['author'])['thumb'].mean().reset_index().sort_values("thumb",ascending=False)
df3_1 = df3[:10]
attr = df3_1.author
v2 = df3_1.thumb
bar = Bar("authors by thumb")
bar.add("thumb", attr, v2, mark_line=["average"])
attr = df2_1.author
v2 = df2_1.favorite
bar_1 = Bar("authors by favorite")
bar_1.add("by favorite", attr, v2, mark_line=["average"])

bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="0fd8887024174bd1a81cbfa02ab035a5" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_0fd8887024174bd1a81cbfa02ab035a5 = echarts.init(document.getElementById('0fd8887024174bd1a81cbfa02ab035a5'), 'light', {renderer: 'canvas'});
#
# var option_0fd8887024174bd1a81cbfa02ab035a5 = {
#     "title": [
#         {
#             "text": "authors by thumb",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 4843825,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "thumb",
#             "data": [
#                 257.0,
#                 34.0,
#                 25.666666666666668,
#                 21.0,
#                 20.0,
#                 18.142857142857142,
#                 18.0,
#                 18.0,
#                 17.0,
#                 17.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 4843825
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "thumb"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "Ella",
#                 "\u4e94\u661f\u5c0f\u5175",
#                 "\u5f20\u5c0f\u748b",
#                 "\u8fa9\u624b\u674e\u6155\u9633",
#                 "\u6e05\u98ce\u5f90\u6765028",
#                 "Anne",
#                 "Danbchpk",
#                 "lison",
#                 "oweni",
#                 "\u683c\u7af9\u96c6"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_0fd8887024174bd1a81cbfa02ab035a5.setOption(option_0fd8887024174bd1a81cbfa02ab035a5);
#
#     });
# </script>

# %%
bar_1
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="fa2714b3c3114fed872265422431d3fc" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_fa2714b3c3114fed872265422431d3fc = echarts.init(document.getElementById('fa2714b3c3114fed872265422431d3fc'), 'light', {renderer: 'canvas'});
#
# var option_fa2714b3c3114fed872265422431d3fc = {
#     "title": [
#         {
#             "text": "authors by favorite",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 2907497,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "by favorite",
#             "data": [
#                 317.3333333333333,
#                 311.0,
#                 134.0,
#                 126.33333333333333,
#                 109.0,
#                 96.0,
#                 92.0,
#                 91.0,
#                 82.0,
#                 69.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 2907497
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "by favorite"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u5f20\u5c0f\u748b",
#                 "Ella",
#                 "\u672a\u7720",
#                 "lison",
#                 "\u6e05\u98ce\u5f90\u6765028",
#                 "\u4e94\u661f\u5c0f\u5175",
#                 "oweni",
#                 "\u5c0f\u674e\u6ca1\u6709\u5b50",
#                 "Danbchpk",
#                 "\u683c\u7af9\u96c6"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_fa2714b3c3114fed872265422431d3fc.setOption(option_fa2714b3c3114fed872265422431d3fc);
#
#     });
# </script>

# %%
df["author"].describe()
# Out:
# count      201
# unique      87
# top       蓝狐笔记
# freq        24
# Name: author, dtype: object

# %%
df[df["thumb"]>50]
# Out:
#      Unnamed: 0 author        date  favorite  thumb  \
# 120         120   Ella  2018/03/07       311    257
# 141         141   Anne  2018/02/12       210     59
# 181         181   硅谷密探  2017/11/11       313     75
#
#                           title                                     title_href
# 120  大家好，我是区块链本人。今天，我要给你们介绍我的家族  http://www.woshipm.com/blockchain/952915.html
# 141             透彻解析区块链、比特币、ICO  http://www.woshipm.com/blockchain/938259.html
# 181   区块链将如何重新定义世界？（本质、行业现状、挑战）  http://www.woshipm.com/blockchain/843635.html

# %%
df[df["thumb"]>50].describe()
# Out:
#        Unnamed: 0    favorite       thumb
# count    3.000000    3.000000    3.000000
# mean   147.333333  278.000000  130.333333
# std     30.989245   58.898217  109.987878
# min    120.000000  210.000000   59.000000
# 25%    130.500000  260.500000   67.000000
# 50%    141.000000  311.000000   75.000000
# 75%    161.000000  312.000000  166.000000
# max    181.000000  313.000000  257.000000

# %%
df[df["favorite"]>50]
# Out:
#      Unnamed: 0    author        date  favorite  thumb  \
# 19           19       秦汗青  2018/08/10        52     11
# 21           21  Danbchpk  2018/07/26        82     18
# 74           74        水伯  2018/04/18        51     17
# 76           76   好青年Hans  2018/04/16        54     14
# 77           77     oweni  2018/04/16        92     17
# 78           78       格竹集  2018/04/16        69     17
# 80           80        跹尘  2018/04/12        57      5
# 84           84      五星小兵  2018/04/03        96     34
# 89           89     纸盒小卡车  2018/03/31        58      9
# 99           99     区块链老垚  2018/03/23        53     16
# 100         100      囧囧有神  2018/03/22        55     12
# 104         104     lison  2018/03/17        77      8
# 105         105     lison  2018/03/16        80     10
# 110         110     lison  2018/03/12       222     36
# 112         112      蓝狐笔记  2018/03/08        54      4
# 115         115      蓝狐笔记  2018/03/07        53     11
# 120         120      Ella  2018/03/07       311    257
# 129         129        未眠  2018/02/28       134     15
# 133         133     Alice  2018/02/28        81     21
# 139         139     辩手李慕阳  2018/02/22        57     21
# 141         141      Anne  2018/02/12       210     59
# 143         143     Alice  2018/02/10        82     22
# 149         149       创业邦  2018/01/29       134     24
# 151         151      蓝狐笔记  2018/01/27        85     19
# 153         153       张小璋  2018/01/23        87      9
# 154         154       张小璋  2018/01/22       480     41
# 155         155       张小璋  2018/01/22       385     27
# 157         157        米可  2018/01/21        53      7
# 171         171      Anne  2018/01/13        83     34
# 174         174       创业邦  2018/01/11        76      6
# 177         177     小李没有子  2018/01/04       215     42
# 179         179       李小新  2017/12/19        60      7
# 181         181      硅谷密探  2017/11/11       313     75
# 183         183     Alice  2017/10/24        65      6
# 185         185        极简  2017/09/21        58     15
# 187         187     Alice  2017/09/04       112     32
# 195         195      蓝狐笔记  2016/10/20        66     11
# 197         197  人人都是产品经理  2016/10/17        64     10
# 198         198       亿欧网  2016/09/06        77     11
# 200         200   清风徐来028  2016/01/29       109     20
#
#                               title  \
# 19                租房痛点如何解决？来看看区块链技术
# 21                      如何理解区块链新商业？
# 74                 “区块链钱包”的技术颠覆在哪里？
# 76   从产品底层设计和活动运营角度解析：区块链落地应用——网易星球
# 77              关于比特币和区块链，你所知道的都对吗？
# 78                    区块链技术的商业潜力与局限
# 80                   3点看产品经理对区块链的认知
# 84                      区块链相关落地应用分析
# 89               区块链带来互联网 3.0 革命全景图
# 99        深入浅出：从一笔比特币交易的生命周期看懂区块链技术
# 100          逐层揭秘：区块链的运作原理、存在问题以及前景
# 104               从零认识区块链（下）：区块链的应用
# 105              从零认识区块链（中）：区块链技术解密
# 110               从零认识区块链（上）：从比特币谈起
# 112               如何理解区块链的产品、平台和协议？
# 115         区块链的应用案例：如果能落地，区块链并不是空气
# 120      大家好，我是区块链本人。今天，我要给你们介绍我的家族
# 129                    为什么你需要了解区块链？
# 133              这波区块链浪潮背后有什么机遇和陷阱？
# 139     有一种焦虑叫：我没有加入3点钟社群，会不会错过区块链！
# 141                 透彻解析区块链、比特币、ICO
# 143                  2018，趁热再说几句区块链
# 149                      区块链入门：幼儿园版
# 151               聚合理论走向终结与区块链时代的开启
# 153               一个产品经理的区块链学习指南（三）
# 154               一个产品经理的区块链学习指南（二）
# 155               一个产品经理的区块链学习指南（一）
# 157          现在的区块链技术，正如 1993 年的互联网
# 171                    区块链与裸照（通俗科普）
# 174                         区块链与新零售
# 177                    区块链对产品意味着什么？
# 179                     人工智能和区块链的融合
# 181       区块链将如何重新定义世界？（本质、行业现状、挑战）
# 183            从比特币的起源说起，谈谈区块链的前世今生
# 185                  深度剖析区块链技术的产品价值
# 187     5000字彻底读懂疯狂的“ICO、区块链、比特币”江湖
# 195               区块链社交，会颠覆现有社交网络吗?
# 197                  区块链其实是比特币背后的技术
# 198                 拼了，用潜规则告诉你区块链是啥
# 200            区块链，2016年互联网金融唯一的风口？
#
#                                          title_href
# 19   http://www.woshipm.com/blockchain/1237492.html
# 21   http://www.woshipm.com/blockchain/1163937.html
# 74    http://www.woshipm.com/blockchain/996661.html
# 76    http://www.woshipm.com/blockchain/991028.html
# 77    http://www.woshipm.com/blockchain/994824.html
# 78    http://www.woshipm.com/blockchain/993267.html
# 80    http://www.woshipm.com/blockchain/990275.html
# 84    http://www.woshipm.com/blockchain/981666.html
# 89    http://www.woshipm.com/blockchain/979000.html
# 99    http://www.woshipm.com/blockchain/962922.html
# 100   http://www.woshipm.com/blockchain/953408.html
# 104   http://www.woshipm.com/blockchain/957048.html
# 105   http://www.woshipm.com/blockchain/956842.html
# 110   http://www.woshipm.com/blockchain/956320.html
# 112   http://www.woshipm.com/blockchain/953485.html
# 115   http://www.woshipm.com/blockchain/953445.html
# 120   http://www.woshipm.com/blockchain/952915.html
# 129   http://www.woshipm.com/blockchain/946591.html
# 133   http://www.woshipm.com/blockchain/945340.html
# 139   http://www.woshipm.com/blockchain/940745.html
# 141   http://www.woshipm.com/blockchain/938259.html
# 143   http://www.woshipm.com/blockchain/936757.html
# 149   http://www.woshipm.com/blockchain/926715.html
# 151   http://www.woshipm.com/blockchain/925315.html
# 153   http://www.woshipm.com/blockchain/918648.html
# 154   http://www.woshipm.com/blockchain/918646.html
# 155   http://www.woshipm.com/blockchain/918644.html
# 157   http://www.woshipm.com/blockchain/917657.html
# 171   http://www.woshipm.com/blockchain/909967.html
# 174   http://www.woshipm.com/blockchain/904324.html
# 177   http://www.woshipm.com/blockchain/897360.html
# 179   http://www.woshipm.com/blockchain/882152.html
# 181   http://www.woshipm.com/blockchain/843635.html
# 183   http://www.woshipm.com/blockchain/826277.html
# 185   http://www.woshipm.com/blockchain/794423.html
# 187   http://www.woshipm.com/blockchain/775779.html
# 195   http://www.woshipm.com/blockchain/431977.html
# 197   http://www.woshipm.com/blockchain/421888.html
# 198   http://www.woshipm.com/blockchain/409833.html
# 200   http://www.woshipm.com/blockchain/276726.html

# %%
df[df["favorite"]>50].describe()
# Out:
#        Unnamed: 0    favorite       thumb
# count   40.000000   40.000000   40.000000
# mean   132.350000  115.050000   25.750000
# std     47.459862   99.235527   40.350865
# min     19.000000   51.000000    4.000000
# 25%     99.750000   57.750000   10.000000
# 50%    140.000000   78.500000   16.500000
# 75%    174.750000  109.750000   24.750000
# max    200.000000  480.000000  257.000000

# %%
df[(df["thumb"]>50)&(df["favorite"]>50)]
# Out:
#      Unnamed: 0 author        date  favorite  thumb  \
# 120         120   Ella  2018/03/07       311    257
# 141         141   Anne  2018/02/12       210     59
# 181         181   硅谷密探  2017/11/11       313     75
#
#                           title                                     title_href
# 120  大家好，我是区块链本人。今天，我要给你们介绍我的家族  http://www.woshipm.com/blockchain/952915.html
# 141             透彻解析区块链、比特币、ICO  http://www.woshipm.com/blockchain/938259.html
# 181   区块链将如何重新定义世界？（本质、行业现状、挑战）  http://www.woshipm.com/blockchain/843635.html
