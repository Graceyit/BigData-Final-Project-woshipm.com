# %%
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt

df = pd.read_csv('分析评测.csv') 

plt.rcParams['font.sans-serif']=['SimHei'] 
plt.rcParams['axes.unicode_minus']=False 

author_counts=df['author'].value_counts()[:10].sort_values(ascending=False) 
author = pd.DataFrame(author_counts)
fig = plt.figure(figsize=(14,7)) 
plt.bar(author.index, author.author,color = '#4584b6',edgecolor = '#4584b6') 

plt.title('top 10 author') 
plt.xlabel('author')
plt.ylabel('counts')
plt.show()

# %%
import seaborn as sns
sns.set(font='SimHei') 
pd_df = df.groupby(['author'])['thumb'].mean().reset_index().sort_values("thumb",ascending=False) [:10]
ax = sns.barplot(x='author', y='thumb',data=pd_df,palette=("ch:2.5,-.2,dark=.3")) 
plt.title('author_thumb', color='black', fontsize=15, weight='bold')
# Out:
# Text(0.5,1,'author_thumb')

# %%
thumb_favorite = df[['thumb','favorite']]
ax4 = thumb_favorite.plot(kind = 'scatter',x='thumb',y='favorite',color = '#575ed8',s=80,fontsize=24)
ax4.set_title("thumb with favorite count",fontsize=20)
# Out:
# Text(0.5,1,'thumb with favorite count')

# %%
df["author"].describe()
# Out:
# count      1263
# unique      869
# top       Nairo
# freq         20
# Name: author, dtype: object

# %%
df[df["thumb"]>50].describe()
# Out:
#         Unnamed: 0     favorite       thumb
# count   177.000000   177.000000  177.000000
# mean    759.751412   341.135593  101.118644
# std     334.740869   317.339855   74.709685
# min      10.000000    24.000000   51.000000
# 25%     493.000000   169.000000   63.000000
# 50%     750.000000   260.000000   79.000000
# 75%    1062.000000   396.000000  108.000000
# max    1260.000000  2456.000000  709.000000

# %%
df[df["favorite"]>50].describe()
# Out:
#         Unnamed: 0     favorite       thumb
# count   789.000000   789.000000  789.000000
# mean    719.666667   167.029151   40.803549
# std     348.860646   189.494634   48.925596
# min       4.000000    51.000000    2.000000
# 25%     417.000000    73.000000   17.000000
# 50%     751.000000   110.000000   26.000000
# 75%    1022.000000   183.000000   47.000000
# max    1261.000000  2456.000000  709.000000

# %%
df[(df["thumb"]>50)&(df["favorite"]>50)].describe()
# Out:
#         Unnamed: 0     favorite       thumb
# count   174.000000   174.000000  174.000000
# mean    765.620690   346.454023  101.701149
# std     334.369694   317.444776   75.217083
# min      10.000000    52.000000   51.000000
# 25%     507.250000   172.250000   63.000000
# 50%     753.000000   261.500000   79.500000
# 75%    1063.500000   410.250000  111.000000
# max    1260.000000  2456.000000  709.000000
